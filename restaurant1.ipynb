# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedangini-Kenma/Vedangini-Kenma/blob/main/restaurant1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1.   **Identifing** **Outliers** **with** **IQR**
# 2.   **Trimming**

# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path='/content/drive/MyDrive/restaurants  - Sheet1.csv'
df=pd.read_csv(path)
df
# Out:
#                                     name  ...            region
# 0          Ardor 2.1 Restaurant & Lounge  ...     central delhi
# 1                            Hotel Amara  ...       south delhi
# 2                          Southwest Inn  ...       south delhi
# 3    2 Fup of Hotel Country Inn & Suites  ...       south delhi
# 4                Banquet of Bite Bikaner  ...  south west delhi
# ..                                   ...  ...               ...
# 494                             narulas   ...     central delhi
# 495                             pal inn   ...        west delhi
# 496                           love grill  ...  north east delhi
# 497                    adish restaurant   ...      south delhi
# 498                       pind balluchi   ...       south delhi
#
# [499 rows x 7 columns]

# %% [markdown]
# **Identifing** **Outliers** **with** **IQR**

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (499, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             499 non-null    object
#  1   max seats        499 non-null    int64
#  2   price per plate  499 non-null    object
#  3   stars            499 non-null    float64
#  4   views            499 non-null    int64
#  5   min seats        499 non-null    float64
#  6   region           499 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 27.4+ KB
# None
#          max seats       stars         views   min seats
# count   499.000000  499.000000    499.000000  499.000000
# mean    129.843687    3.414629   1219.953908   18.083768
# std     212.718736    0.703553   1588.829098   34.193408
# min       4.000000    2.000000      1.000000    1.000000
# 25%      50.000000    3.000000    381.500000    5.000000
# ...

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter( df['views'],df['stars'])
ax.set_xlabel('view')
ax.set_ylabel('star')
print("variation in views though stars are same")
plt.show()
# Out:
# variation in views though stars are same

# %% [markdown]
# **comparing** **after** **trimming**

# %%
new_df = df[(df['views'] >= 3170 ) | (df['views'] <= 1292)]
#cf = cf[cf]
new_df
# Out:
#                                      name  ...            region
# 0           Ardor 2.1 Restaurant & Lounge  ...     central delhi
# 2                           Southwest Inn  ...       south delhi
# 3     2 Fup of Hotel Country Inn & Suites  ...       south delhi
# 4                 Banquet of Bite Bikaner  ...  south west delhi
# 5      Banquet Hall of The Terrace Sandoz  ...  north west delhi
# ..                                    ...  ...               ...
# 493  taste vishal hotel vishal residency   ...       south delhi
# 494                              narulas   ...     central delhi
# 495                              pal inn   ...        west delhi
# 496                            love grill  ...  north east delhi
# 498                        pind balluchi   ...       south delhi
#
# [356 rows x 7 columns]

# %% [markdown]
# **Plotting** **Graph** **to** **underatand**

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['views'])
plt.subplot(2,2,2)
sns.boxplot(df['views'])
plt.subplot(2,2,3)
sns.distplot(new_df['views'])
plt.subplot(2,2,4)
sns.boxplot(new_df['views'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %% [markdown]
# **Restaurants** **having** **profitable** **business**

# %%
df.to_dict('records')
# Out:
# [{'max seats': 150,
#   'min seats': 10.0,
#   'name': 'Ardor 2.1 Restaurant & Lounge',
#   'price per plate': '850',
#   'region': 'central delhi',
#   'stars': 4.5,
#   'views': 22466},
#  {'max seats': 100,
#   'min seats': 10.0,
#   'name': 'Hotel Amara',
#   'price per plate': '1000',
#   'region': 'south delhi',
#   'stars': 4.5,
#   'views': 1715},
#  {'max seats': 150,
#   'min seats': 10.0,
#   'name': 'Southwest Inn',
#   'price per plate': '850',
#   'region': 'south delhi',
#   'stars': 3.0,
#   'views': 946},
#  {'max seats': 125,
#   'min seats': 10.0,
#   'name': '2 Fup of Hotel Country Inn & Suites',
#   'price per plate': '1200',
#   'region': 'south delhi',
#   'stars': 4.3,
#   'views': 4883},
#  {'max seats': 100,
#   'min seats': 30.0,
#   'name': 'Banquet of Bite Bikaner',
#   'price per plate': '700',
#   'region': 'south west delhi',
#   'stars': 4.4,
#   'views': 5490},
#  {'max seats': 300,
#   'min seats': 50.0,
# ...

# %%
df.shape
# Out:
# (499, 7)

# %%
new_df.shape
# Out:
# (356, 7)
